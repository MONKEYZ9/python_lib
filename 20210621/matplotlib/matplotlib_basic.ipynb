# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.plot([0, 1, 2, 3, 4], [20, 34, 54, 10, 66])
# 키 벨류 형식으로 해서 들어가는거야

plt.title("Welcome matplotlib")
plt.xlabel("index")
plt.ylabel("value")
# Out:
# Text(0, 0.5, 'value')

# %%
df = pd.read_csv('C:/Users/mingzzang/Desktop/20210617/PART17-20210621T020629Z-001/PART17/dataset/commerce.csv', encoding='unicode_escape')

# 날짜를 자르고 봐야 조금 편하다는 거야
df['parse_InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
# 년월일로 쪼개
df['year_InvoiceDate'] = df['parse_InvoiceDate'].dt.year
df['month_InvoiceDate'] = df['parse_InvoiceDate'].dt.month
df['day_InvoiceDate'] = df['parse_InvoiceDate'].dt.day

df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  \
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541904  12/9/2011 12:50       0.85     12680.0          France
# 541905  12/9/2011 12:50       2.10     12680.0          France
# 541906  12/9/2011 12:50       4.15     12680.0          France
# 541907  12/9/2011 12:50       4.15     12680.0          France
# 541908  12/9/2011 12:50       4.95     12680.0          France
#
#          parse_InvoiceDate  year_InvoiceDate  month_InvoiceDate  \
# 0      2010-12-01 08:26:00              2010                 12
# 1      2010-12-01 08:26:00              2010                 12
# 2      2010-12-01 08:26:00              2010                 12
# 3      2010-12-01 08:26:00              2010                 12
# 4      2010-12-01 08:26:00              2010                 12
# ...                    ...               ...                ...
# 541904 2011-12-09 12:50:00              2011                 12
# 541905 2011-12-09 12:50:00              2011                 12
# 541906 2011-12-09 12:50:00              2011                 12
# 541907 2011-12-09 12:50:00              2011                 12
# 541908 2011-12-09 12:50:00              2011                 12
#
#         day_InvoiceDate
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
# ...                 ...
# 541904                9
# 541905                9
# 541906                9
# 541907                9
# 541908                9
#
# [541909 rows x 12 columns]

# %%
# 그래프를 그려보자
import numpy as np
import warnings

warnings.filterwarnings(action='ignore')
# 총 5개를 만들거야 nrows=5, ncols=1 5행 1열로 보여준다는거야
# figure, ((ax1), (ax2), (ax3), (ax4), (ax5)) = plt.subplots(nrows=5, ncols=1)
# # 4행 1열 뽑아내기
# figure, ((ax1), (ax2), (ax3), (ax4)) = plt.subplots(nrows=4, ncols=1)
# # 2행 3열 뽑아내기
# figure, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(nrows=2, ncols=3)
# # 6행 2열 뽑아내기
# figure, ((ax1, ax2), (ax3, ax4), (ax3, ax4), (ax5, ax6), (ax7, ax8), (ax9, ax10)) = plt.subplots(nrows=6, ncols=2)
# 3행 4열 뽑아내기
figure, ((ax1, ax2, ax3, ax4),
 (ax5, ax6, ax7, ax8), 
 (ax9, ax10, ax11, ax12)) = plt.subplots(nrows=3, ncols=4)

figure.set_size_inches(9, 8) #사이즈

# %%
year_InvoiceDate_sum = df.groupby('year_InvoiceDate').UnitPrice.sum()
year_InvoiceDate_sum
# Out:
# year_InvoiceDate
# 2010    2.605209e+05
# 2011    2.238283e+06
# Name: UnitPrice, dtype: float64

# %%
ax1.plot(year_InvoiceDate_sum.index, year_InvoiceDate_sum.values)
ax1.set_xticks(np.unique(df["year_InvoiceDate"]))
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('C:/Users/mingzzang/Desktop/20210617/PART17-20210621T020629Z-001/PART17/dataset/commerce.csv', encoding='unicode_escape')

# 날짜를 자르고 봐야 조금 편하다는 거야
df['parse_InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
# 년월일로 쪼개
df['year_InvoiceDate'] = df['parse_InvoiceDate'].dt.year
df['month_InvoiceDate'] = df['parse_InvoiceDate'].dt.month
df['day_InvoiceDate'] = df['parse_InvoiceDate'].dt.day

df
# 월별로 구분하는거야
month_InvoiceDate_sum = df.groupby('month_InvoiceDate').UnitPrice.sum()
# ax2.scatter(month_InvoiceDate_sum.index, month_InvoiceDate_sum.values)
# autopct='%0.2f%%' 소수점 나타내주는거야
ax2.pie( month_InvoiceDate_sum.values, labels=month_InvoiceDate_sum.index, autopct='%0.2f%%' )
ax2.set_xticks(np.unique(df["month_InvoiceDate"]))
# 파이차트로 보는거야
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-9a3053fab66c> in <module>
#      16 # ax2.scatter(month_InvoiceDate_sum.index, month_InvoiceDate_sum.values)
#      17 # autopct='%0.2f%%' 소수점 나타내주는거야
# ---> 18 ax2.pie( month_InvoiceDate_sum.values, labels=month_InvoiceDate_sum.index, autopct='%0.2f%%' )
#      19 ax2.set_xticks(np.unique(df["month_InvoiceDate"]))
#      20 # 파이차트로 보는거야
#
# NameError: name 'ax2' is not defined
